# %%
import cv2
import numpy as np

img_path = r"E:\image\football.jpg"

image = cv2.imread(img_path)
image = cv2.resize(image, (1580, 720))

text = "rolando"
org = (500, 700)
font = cv2.FONT_HERSHEY_COMPLEX
fontScale = 6
color = (0,255,0)  #(B, G, R)
thickness = 7
lineType = cv2.LINE_AA
bottomLeftOrigin = False

# Syntax>> cv2.putText(image, text, org, font, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]])

img_text = cv2.putText(image, text, org, font, fontScale, color, thickness, lineType, bottomLeftOrigin)

cv2.imshow("Text Image", img_text)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
 
img_path = r"E:\image\football.jpg"

image = cv2.imread(img_path)
 
image = cv2.resize(image, (1280, 720))
 
text = "ROLANDO"
org = (100, 200)
font = cv2.FONT_HERSHEY_COMPLEX
fontScale = 6
 
color = (55,255,255)  #(B, G, R)
thickness = 3
lineType = cv2.LINE_AA
bottomLeftOrigin = True
 
# cv2.putText(image, text, org, font, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]])
img_text = cv2.putText(image, text, org, font, fontScale, color, thickness, lineType, bottomLeftOrigin)
 
 
cv2.imshow("Text Image", img_text)
 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
 
img_path = r"E:\image\football.jpg"
 
image = cv2.imread(img_path)
 
image = cv2.resize(image, (1280, 720))
 
text = "OPENCV"
org = (100, 200)
font = cv2.FONT_HERSHEY_COMPLEX
fontScale = 6
 
color = (255,0,0)  #(B, G, R)
thickness = 8
lineType = cv2.LINE_AA
bottomLeftOrigin = True
 
# cv2.putText(image, text, org, font, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]])
img_text = cv2.putText(image, text, org, font, fontScale, color, thickness, lineType, bottomLeftOrigin)
 
img_text = cv2.putText(image, text, org, font, fontScale, color, thickness, lineType, bottomLeftOrigin=False)
 
cv2.imshow("Text Image", img_text)
 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img_path = r"E:\image\football.jpg"

image = cv2.imread(img_path)

image = cv2.resize(image, (1280, 720))

text = "ROBOTICS FOR UNITED INDIA"
org = (50, 100)
font = cv2.FONT_HERSHEY_COMPLEX_SMALL
fontScale = 4

color = (0,6,23)  #(B, G, R)
thickness = 3
lineType = cv2.LINE_AA
bottomLeftOrigin = True

# cv2.putText(image, text, org, font, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]])
img_text = cv2.putText(image, text, org, font, fontScale, color, thickness, lineType, bottomLeftOrigin)

img_text = cv2.putText(image, text, org, font, fontScale, color, thickness, lineType, bottomLeftOrigin=False)

cv2.imshow("Text Image", img_text)

cv2.waitKey(0)
cv2.destroyAllWindows()
